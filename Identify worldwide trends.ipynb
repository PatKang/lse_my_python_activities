# %% [markdown]
# ### Prepare the Workstation

# %%
import yaml 
from yaml.loader import SafeLoader

# %%
twitter_creds = yaml.safe_load(open('twitter_tmp.yaml', 'r').read())

# %%
twitter_creds.keys()
# Out:
# dict_keys(['api_key', 'api_secret_key', 'access_token', 'access_token_secret'])

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\patri\anaconda3\lib\site-packages (1.19.3)

# %%
from twitter import *

# %%
# Now we can define the access token, access token secret, api key and api key secret. Keep the Order as that.
twitter_api = Twitter(auth = OAuth(twitter_creds['access_token'],
                                   twitter_creds['access_token_secret'],
                                   twitter_creds['api_key'],
                                   twitter_creds['api_secret_key']))

# %%
# Check if we have an active connection
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000019697CDBC40>

# %% [markdown]
# ### Worldwide trends
#
# We will create a list of all trending topics around the world.

# %%
# Identify a worldwide trend
trends_worldwide = twitter_api.trends.available()

# How many trends are available?
print(len(trends_worldwide))

# Example of trends_worldwide
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %%
# As the output tells us there are 467 trends available in the world, what if we wanted to check the trend in one city?

list_of_names = [_['name'] for _ in trends_worldwide]

# List of first 10 cities
list_of_names[0:10]
# Out:
# ['Worldwide',
#  'Winnipeg',
#  'Ottawa',
#  'Quebec',
#  'Montreal',
#  'Toronto',
#  'Edmonton',
#  'Calgary',
#  'Vancouver',
#  'Birmingham']

# %%
# Find our city
our_city = 'Seoul'

# Create a variable
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# View the output
print(len(list_of_names_our_city))

# Use the index to find Seoul
list_of_names_our_city[0]
# Out:
# 1
# {'name': 'Seoul',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/1132599',
#  'parentid': 23424868,
#  'country': 'Korea',
#  'woeid': 1132599,
#  'countryCode': 'KR'}

# %%
# Now we can check the trends for a city. In the documentation we are told to use woeid 
list_of_names_our_city[0]['woeid']
# Out:
# 1132599

# %%
# Seoul's woeid is 1132599 let's find some other woids
home_city = 'Berlin'

list_of_names_home = [_ for _ in trends_worldwide if _['name'] == home_city]

print(len(list_of_names_home))

list_of_names_home[0]['woeid']
# Out:
# 1
# 638242

# %% [markdown]
# ### Identify common trends between two cities
#
# Now that we have identified trends and learned how to get the woeid of a city, let's identify and compare common trends between berlin and seoul

# %%
# Create trends in seoul variable

seoul_trends = twitter_api.trends.place(_id = list_of_names_our_city[0]['woeid'])

# View the output
seoul_trends
# Out:
# [{'trends': [{'name': '#jhope_MORE',
#     'url': 'http://twitter.com/search?q=%23jhope_MORE',
#     'promoted_content': None,
#     'query': '%23jhope_MORE',
#     'tweet_volume': 2450658},
#    {'name': '#누구보다_빠른_7월_최애_선점',
#     'url': 'http://twitter.com/search?q=%23%EB%88%84%EA%B5%AC%EB%B3%B4%EB%8B%A4_%EB%B9%A0%EB%A5%B8_7%EC%9B%94_%EC%B5%9C%EC%95%A0_%EC%84%A0%EC%A0%90',
#     'promoted_content': None,
#     'query': '%23%EB%88%84%EA%B5%AC%EB%B3%B4%EB%8B%A4_%EB%B9%A0%EB%A5%B8_7%EC%9B%94_%EC%B5%9C%EC%95%A0_%EC%84%A0%EC%A0%90',
#     'tweet_volume': None},
#    {'name': '커밍아웃',
#     'url': 'http://twitter.com/search?q=%EC%BB%A4%EB%B0%8D%EC%95%84%EC%9B%83',
#     'promoted_content': None,
#     'query': '%EC%BB%A4%EB%B0%8D%EC%95%84%EC%9B%83',
#     'tweet_volume': 13260},
#    {'name': '트친 메뉴판',
#     'url': 'http://twitter.com/search?q=%22%ED%8A%B8%EC%B9%9C+%EB%A9%94%EB%89%B4%ED%8C%90%22',
#     'promoted_content': None,
#     'query': '%22%ED%8A%B8%EC%B9%9C+%EB%A9%94%EB%89%B4%ED%8C%90%22',
#     'tweet_volume': None},
#    {'name': '문송안함',
#     'url': 'http://twitter.com/search?q=%EB%AC%B8%EC%86%A1%EC%95%88%ED%95%A8',
#     'promoted_content': None,
#     'query': '%EB%AC%B8%EC%86%A1%EC%95%88%ED%95%A8',
#     'tweet_volume': None},
#    {'name': '#모어_다운후스밍해',
#     'url': 'http://twitter.com/search?q=%23%EB%AA%A8%EC%96%B4_%EB%8B%A4%EC%9A%B4%ED%9B%84%EC%8A%A4%EB%B0%8D%ED%95%B4',
#     'promoted_content': None,
#     'query': '%23%EB%AA%A8%EC%96%B4_%EB%8B%A4%EC%9A%B4%ED%9B%84%EC%8A%A4%EB%B0%8D%ED%95%B4',
#     'tweet_volume': 23044},
#    {'name': '사망원인',
#     'url': 'http://twitter.com/search?q=%EC%82%AC%EB%A7%9D%EC%9B%90%EC%9D%B8',
#     'promoted_content': None,
#     'query': '%EC%82%AC%EB%A7%9D%EC%9B%90%EC%9D%B8',
#     'tweet_volume': None},
#    {'name': '나의 전생',
#     'url': 'http://twitter.com/search?q=%22%EB%82%98%EC%9D%98+%EC%A0%84%EC%83%9D%22',
#     'promoted_content': None,
#     'query': '%22%EB%82%98%EC%9D%98+%EC%A0%84%EC%83%9D%22',
#     'tweet_volume': None},
#    {'name': '주류박람회',
#     'url': 'http://twitter.com/search?q=%EC%A3%BC%EB%A5%98%EB%B0%95%EB%9E%8C%ED%9A%8C',
#     'promoted_content': None,
#     'query': '%EC%A3%BC%EB%A5%98%EB%B0%95%EB%9E%8C%ED%9A%8C',
#     'tweet_volume': None},
#    {'name': '#더_킹이홉스럽게_모어',
#     'url': 'http://twitter.com/search?q=%23%EB%8D%94_%ED%82%B9%EC%9D%B4%ED%99%89%EC%8A%A4%EB%9F%BD%EA%B2%8C_%EB%AA%A8%EC%96%B4',
#     'promoted_content': None,
#     'query': '%23%EB%8D%94_%ED%82%B9%EC%9D%B4%ED%99%89%EC%8A%A4%EB%9F%BD%EA%B2%8C_%EB%AA%A8%EC%96%B4',
#     'tweet_volume': 10965},
#    {'name': '꼬들 182',
#     'url': 'http://twitter.com/search?q=%22%EA%BC%AC%EB%93%A4+182%22',
#     'promoted_content': None,
#     'query': '%22%EA%BC%AC%EB%93%A4+182%22',
#     'tweet_volume': None},
#    {'name': '#이해시를_보면_무조건_1년전_플앱',
#     'url': 'http://twitter.com/search?q=%23%EC%9D%B4%ED%95%B4%EC%8B%9C%EB%A5%BC_%EB%B3%B4%EB%A9%B4_%EB%AC%B4%EC%A1%B0%EA%B1%B4_1%EB%85%84%EC%A0%84_%ED%94%8C%EC%95%B1',
#     'promoted_content': None,
#     'query': '%23%EC%9D%B4%ED%95%B4%EC%8B%9C%EB%A5%BC_%EB%B3%B4%EB%A9%B4_%EB%AC%B4%EC%A1%B0%EA%B1%B4_1%EB%85%84%EC%A0%84_%ED%94%8C%EC%95%B1',
#     'tweet_volume': None},
#    {'name': '아기대통령',
#     'url': 'http://twitter.com/search?q=%EC%95%84%EA%B8%B0%EB%8C%80%ED%86%B5%EB%A0%B9',
#     'promoted_content': None,
#     'query': '%EC%95%84%EA%B8%B0%EB%8C%80%ED%86%B5%EB%A0%B9',
#     'tweet_volume': 16445},
#    {'name': '불륜미화',
#     'url': 'http://twitter.com/search?q=%EB%B6%88%EB%A5%9C%EB%AF%B8%ED%99%94',
#     'promoted_content': None,
#     'query': '%EB%B6%88%EB%A5%9C%EB%AF%B8%ED%99%94',
#     'tweet_volume': None},
#    {'name': '루키즈 공개',
#     'url': 'http://twitter.com/search?q=%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EA%B3%B5%EA%B0%9C%22',
#     'promoted_content': None,
#     'query': '%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EA%B3%B5%EA%B0%9C%22',
#     'tweet_volume': None},
#    {'name': '루키즈 계정',
#     'url': 'http://twitter.com/search?q=%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EA%B3%84%EC%A0%95%22',
#     'promoted_content': None,
#     'query': '%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EA%B3%84%EC%A0%95%22',
#     'tweet_volume': None},
#    {'name': '조음전기',
#     'url': 'http://twitter.com/search?q=%EC%A1%B0%EC%9D%8C%EC%A0%84%EA%B8%B0',
#     'promoted_content': None,
#     'query': '%EC%A1%B0%EC%9D%8C%EC%A0%84%EA%B8%B0',
#     'tweet_volume': None},
#    {'name': '이상한 변호사',
#     'url': 'http://twitter.com/search?q=%22%EC%9D%B4%EC%83%81%ED%95%9C+%EB%B3%80%ED%98%B8%EC%82%AC%22',
#     'promoted_content': None,
#     'query': '%22%EC%9D%B4%EC%83%81%ED%95%9C+%EB%B3%80%ED%98%B8%EC%82%AC%22',
#     'tweet_volume': None},
#    {'name': '요즘 지하철',
#     'url': 'http://twitter.com/search?q=%22%EC%9A%94%EC%A6%98+%EC%A7%80%ED%95%98%EC%B2%A0%22',
#     'promoted_content': None,
#     'query': '%22%EC%9A%94%EC%A6%98+%EC%A7%80%ED%95%98%EC%B2%A0%22',
#     'tweet_volume': None},
#    {'name': '마침내 완결',
#     'url': 'http://twitter.com/search?q=%22%EB%A7%88%EC%B9%A8%EB%82%B4+%EC%99%84%EA%B2%B0%22',
#     'promoted_content': None,
#     'query': '%22%EB%A7%88%EC%B9%A8%EB%82%B4+%EC%99%84%EA%B2%B0%22',
#     'tweet_volume': None},
#    {'name': '루키즈 시절',
#     'url': 'http://twitter.com/search?q=%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EC%8B%9C%EC%A0%88%22',
#     'promoted_content': None,
#     'query': '%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EC%8B%9C%EC%A0%88%22',
#     'tweet_volume': None},
#    {'name': '이번달도',
#     'url': 'http://twitter.com/search?q=%EC%9D%B4%EB%B2%88%EB%8B%AC%EB%8F%84',
#     'promoted_content': None,
#     'query': '%EC%9D%B4%EB%B2%88%EB%8B%AC%EB%8F%84',
#     'tweet_volume': None},
#    {'name': '중콘 4층',
#     'url': 'http://twitter.com/search?q=%22%EC%A4%91%EC%BD%98+4%EC%B8%B5%22',
#     'promoted_content': None,
#     'query': '%22%EC%A4%91%EC%BD%98+4%EC%B8%B5%22',
#     'tweet_volume': None},
#    {'name': '지하철 사고',
#     'url': 'http://twitter.com/search?q=%22%EC%A7%80%ED%95%98%EC%B2%A0+%EC%82%AC%EA%B3%A0%22',
#     'promoted_content': None,
#     'query': '%22%EC%A7%80%ED%95%98%EC%B2%A0+%EC%82%AC%EA%B3%A0%22',
#     'tweet_volume': 19490},
#    {'name': '대서사시',
#     'url': 'http://twitter.com/search?q=%EB%8C%80%EC%84%9C%EC%82%AC%EC%8B%9C',
#     'promoted_content': None,
#     'query': '%EB%8C%80%EC%84%9C%EC%82%AC%EC%8B%9C',
#     'tweet_volume': None},
#    {'name': '문송 완결',
#     'url': 'http://twitter.com/search?q=%22%EB%AC%B8%EC%86%A1+%EC%99%84%EA%B2%B0%22',
#     'promoted_content': None,
#     'query': '%22%EB%AC%B8%EC%86%A1+%EC%99%84%EA%B2%B0%22',
#     'tweet_volume': None},
#    {'name': '사랑 받으실분',
#     'url': 'http://twitter.com/search?q=%22%EC%82%AC%EB%9E%91+%EB%B0%9B%EC%9C%BC%EC%8B%A4%EB%B6%84%22',
#     'promoted_content': None,
#     'query': '%22%EC%82%AC%EB%9E%91+%EB%B0%9B%EC%9C%BC%EC%8B%A4%EB%B6%84%22',
#     'tweet_volume': None},
#    {'name': '시체자루',
#     'url': 'http://twitter.com/search?q=%EC%8B%9C%EC%B2%B4%EC%9E%90%EB%A3%A8',
#     'promoted_content': None,
#     'query': '%EC%8B%9C%EC%B2%B4%EC%9E%90%EB%A3%A8',
#     'tweet_volume': None},
#    {'name': '소라 생일',
#     'url': 'http://twitter.com/search?q=%22%EC%86%8C%EB%9D%BC+%EC%83%9D%EC%9D%BC%22',
#     'promoted_content': None,
#     'query': '%22%EC%86%8C%EB%9D%BC+%EC%83%9D%EC%9D%BC%22',
#     'tweet_volume': None},
#    {'name': '아킬레스',
#     'url': 'http://twitter.com/search?q=%EC%95%84%ED%82%AC%EB%A0%88%EC%8A%A4',
#     'promoted_content': None,
#     'query': '%EC%95%84%ED%82%AC%EB%A0%88%EC%8A%A4',
#     'tweet_volume': None},
#    {'name': 'srt 탈선',
#     'url': 'http://twitter.com/search?q=%22srt+%ED%83%88%EC%84%A0%22',
#     'promoted_content': None,
#     'query': '%22srt+%ED%83%88%EC%84%A0%22',
#     'tweet_volume': 18691},
#    {'name': '루키즈때',
#     'url': 'http://twitter.com/search?q=%EB%A3%A8%ED%82%A4%EC%A6%88%EB%95%8C',
#     'promoted_content': None,
#     'query': '%EB%A3%A8%ED%82%A4%EC%A6%88%EB%95%8C',
#     'tweet_volume': None},
#    {'name': '물잔나 실장',
#     'url': 'http://twitter.com/search?q=%22%EB%AC%BC%EC%9E%94%EB%82%98+%EC%8B%A4%EC%9E%A5%22',
#     'promoted_content': None,
#     'query': '%22%EB%AC%BC%EC%9E%94%EB%82%98+%EC%8B%A4%EC%9E%A5%22',
#     'tweet_volume': None},
#    {'name': '마도대전',
#     'url': 'http://twitter.com/search?q=%EB%A7%88%EB%8F%84%EB%8C%80%EC%A0%84',
#     'promoted_content': None,
#     'query': '%EB%A7%88%EB%8F%84%EB%8C%80%EC%A0%84',
#     'tweet_volume': None},
#    {'name': '첫콘 4층',
#     'url': 'http://twitter.com/search?q=%22%EC%B2%AB%EC%BD%98+4%EC%B8%B5%22',
#     'promoted_content': None,
#     'query': '%22%EC%B2%AB%EC%BD%98+4%EC%B8%B5%22',
#     'tweet_volume': None},
#    {'name': '팀코리아',
#     'url': 'http://twitter.com/search?q=%ED%8C%80%EC%BD%94%EB%A6%AC%EC%95%84',
#     'promoted_content': None,
#     'query': '%ED%8C%80%EC%BD%94%EB%A6%AC%EC%95%84',
#     'tweet_volume': None},
#    {'name': '막콘 4층',
#     'url': 'http://twitter.com/search?q=%22%EB%A7%89%EC%BD%98+4%EC%B8%B5%22',
#     'promoted_content': None,
#     'query': '%22%EB%A7%89%EC%BD%98+4%EC%B8%B5%22',
#     'tweet_volume': None},
#    {'name': '결심 보고',
#     'url': 'http://twitter.com/search?q=%22%EA%B2%B0%EC%8B%AC+%EB%B3%B4%EA%B3%A0%22',
#     'promoted_content': None,
#     'query': '%22%EA%B2%B0%EC%8B%AC+%EB%B3%B4%EA%B3%A0%22',
#     'tweet_volume': None},
#    {'name': '안무영상',
#     'url': 'http://twitter.com/search?q=%EC%95%88%EB%AC%B4%EC%98%81%EC%83%81',
#     'promoted_content': None,
#     'query': '%EC%95%88%EB%AC%B4%EC%98%81%EC%83%81',
#     'tweet_volume': None},
#    {'name': '청소노동자',
#     'url': 'http://twitter.com/search?q=%EC%B2%AD%EC%86%8C%EB%85%B8%EB%8F%99%EC%9E%90',
#     'promoted_content': None,
#     'query': '%EC%B2%AD%EC%86%8C%EB%85%B8%EB%8F%99%EC%9E%90',
#     'tweet_volume': 17021},
#    {'name': '루키즈 사진',
#     'url': 'http://twitter.com/search?q=%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EC%82%AC%EC%A7%84%22',
#     'promoted_content': None,
#     'query': '%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EC%82%AC%EC%A7%84%22',
#     'tweet_volume': None},
#    {'name': '파란 하늘',
#     'url': 'http://twitter.com/search?q=%22%ED%8C%8C%EB%9E%80+%ED%95%98%EB%8A%98%22',
#     'promoted_content': None,
#     'query': '%22%ED%8C%8C%EB%9E%80+%ED%95%98%EB%8A%98%22',
#     'tweet_volume': None},
#    {'name': '별의 흔적',
#     'url': 'http://twitter.com/search?q=%22%EB%B3%84%EC%9D%98+%ED%9D%94%EC%A0%81%22',
#     'promoted_content': None,
#     'query': '%22%EB%B3%84%EC%9D%98+%ED%9D%94%EC%A0%81%22',
#     'tweet_volume': None},
#    {'name': '맑은 하늘',
#     'url': 'http://twitter.com/search?q=%22%EB%A7%91%EC%9D%80+%ED%95%98%EB%8A%98%22',
#     'promoted_content': None,
#     'query': '%22%EB%A7%91%EC%9D%80+%ED%95%98%EB%8A%98%22',
#     'tweet_volume': None},
#    {'name': '또도가스',
#     'url': 'http://twitter.com/search?q=%EB%98%90%EB%8F%84%EA%B0%80%EC%8A%A4',
#     'promoted_content': None,
#     'query': '%EB%98%90%EB%8F%84%EA%B0%80%EC%8A%A4',
#     'tweet_volume': None},
#    {'name': '러브버그',
#     'url': 'http://twitter.com/search?q=%EB%9F%AC%EB%B8%8C%EB%B2%84%EA%B7%B8',
#     'promoted_content': None,
#     'query': '%EB%9F%AC%EB%B8%8C%EB%B2%84%EA%B7%B8',
#     'tweet_volume': None},
#    {'name': '루키즈 마크',
#     'url': 'http://twitter.com/search?q=%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EB%A7%88%ED%81%AC%22',
#     'promoted_content': None,
#     'query': '%22%EB%A3%A8%ED%82%A4%EC%A6%88+%EB%A7%88%ED%81%AC%22',
#     'tweet_volume': None},
#    {'name': '드디어 시험',
#     'url': 'http://twitter.com/search?q=%22%EB%93%9C%EB%94%94%EC%96%B4+%EC%8B%9C%ED%97%98%22',
#     'promoted_content': None,
#     'query': '%22%EB%93%9C%EB%94%94%EC%96%B4+%EC%8B%9C%ED%97%98%22',
#     'tweet_volume': None},
#    {'name': '하반기 시작',
#     'url': 'http://twitter.com/search?q=%22%ED%95%98%EB%B0%98%EA%B8%B0+%EC%8B%9C%EC%9E%91%22',
#     'promoted_content': None,
#     'query': '%22%ED%95%98%EB%B0%98%EA%B8%B0+%EC%8B%9C%EC%9E%91%22',
#     'tweet_volume': None},
#    {'name': '하늘 너무',
#     'url': 'http://twitter.com/search?q=%22%ED%95%98%EB%8A%98+%EB%84%88%EB%AC%B4%22',
#     'promoted_content': None,
#     'query': '%22%ED%95%98%EB%8A%98+%EB%84%88%EB%AC%B4%22',
#     'tweet_volume': None}],
#   'as_of': '2022-07-01T19:30:59Z',
# 9        10965.0
# 10           NaN
# 11           NaN
# 12       16445.0
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23       19490.0
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30       18691.0
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39       17021.0
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN

# %%
# Since we have a ton of data, we might want to limit the tweets to those with more than 100000 tweets

seoul_trends_over100k = seoul_trends_pd[seoul_trends_pd['tweet_volume'] > 10000]\
.sort_values('tweet_volume', ascending = False)

print(seoul_trends_over100k.shape)
seoul_trends_over100k
# Out:
# (8, 5)
#             name                                                url  \
# 0    #jhope_MORE          http://twitter.com/search?q=%23jhope_MORE
# 5     #모어_다운후스밍해  http://twitter.com/search?q=%23%EB%AA%A8%EC%96...
# 23        지하철 사고  http://twitter.com/search?q=%22%EC%A7%80%ED%95...
# 30        srt 탈선  http://twitter.com/search?q=%22srt+%ED%83%88%E...
# 39         청소노동자  http://twitter.com/search?q=%EC%B2%AD%EC%86%8C...
# 12         아기대통령  http://twitter.com/search?q=%EC%95%84%EA%B8%B0...
# 2           커밍아웃  http://twitter.com/search?q=%EC%BB%A4%EB%B0%8D...
# 9   #더_킹이홉스럽게_모어  http://twitter.com/search?q=%23%EB%8D%94_%ED%8...
#
#    promoted_content                                              query  \
# 0              None                                      %23jhope_MORE
# 5              None  %23%EB%AA%A8%EC%96%B4_%EB%8B%A4%EC%9A%B4%ED%9B...
# 23             None  %22%EC%A7%80%ED%95%98%EC%B2%A0+%EC%82%AC%EA%B3...
# 30             None                       %22srt+%ED%83%88%EC%84%A0%22
# 39             None      %EC%B2%AD%EC%86%8C%EB%85%B8%EB%8F%99%EC%9E%90
# 12             None      %EC%95%84%EA%B8%B0%EB%8C%80%ED%86%B5%EB%A0%B9
# 2              None               %EC%BB%A4%EB%B0%8D%EC%95%84%EC%9B%83
# 9              None  %23%EB%8D%94_%ED%82%B9%EC%9D%B4%ED%99%89%EC%8A...
#
#     tweet_volume
# 0      2450658.0
# 5        23044.0
# 23       19490.0
# 30       18691.0
# 39       17021.0
# 12       16445.0
# 2        13260.0
# 9        10965.0

# %%
# Now we have a list of 8 tweets, let's save this as a csv fle

seoul_trends_over100k.to_csv('seoul_tweets.csv', index = False)

# %% [markdown]
# ### Trends for Berlin
#
# As we are more familiar with the process of defining our town and the tweets lets do the same for berlin

# %%
# Create the trends for Berlin variable, let's find again the ID

our_city = 'Berlin'

list_of_names_berlin = [_ for _ in trends_worldwide if _['name'] == our_city]

print(len(list_of_names_berlin))

list_of_names_home[0]['woeid']
# Out:
# 1
# 638242

# %%
# Got the ID, let's now figure out the trends for this ID

berlin_trends = twitter_api.trends.place(_id = list_of_names_home[0]['woeid'])

berlin_trends
# Out:
# [{'trends': [{'name': '#KulFaZ',
#     'url': 'http://twitter.com/search?q=%23KulFaZ',
#     'promoted_content': None,
#     'query': '%23KulFaZ',
#     'tweet_volume': None},
#    {'name': '#BluesBrothers',
#     'url': 'http://twitter.com/search?q=%23BluesBrothers',
#     'promoted_content': None,
#     'query': '%23BluesBrothers',
#     'tweet_volume': None},
#    {'name': 'Willkür',
#     'url': 'http://twitter.com/search?q=Willk%C3%BCr',
#     'promoted_content': None,
#     'query': 'Willk%C3%BCr',
#     'tweet_volume': None},
#    {'name': '#StrangerThings4',
#     'url': 'http://twitter.com/search?q=%23StrangerThings4',
#     'promoted_content': None,
#     'query': '%23StrangerThings4',
#     'tweet_volume': 372614},
#    {'name': '#DankeWieler',
#     'url': 'http://twitter.com/search?q=%23DankeWieler',
#     'promoted_content': None,
#     'query': '%23DankeWieler',
#     'tweet_volume': None},
#    {'name': 'Maßnahmen',
#     'url': 'http://twitter.com/search?q=Ma%C3%9Fnahmen',
#     'promoted_content': None,
#     'query': 'Ma%C3%9Fnahmen',
#     'tweet_volume': 32783},
#    {'name': '#LauterbachRuecktrittSofort',
#     'url': 'http://twitter.com/search?q=%23LauterbachRuecktrittSofort',
#     'promoted_content': None,
#     'query': '%23LauterbachRuecktrittSofort',
#     'tweet_volume': None},
#    {'name': 'Bremsklotz',
#     'url': 'http://twitter.com/search?q=Bremsklotz',
#     'promoted_content': None,
#     'query': 'Bremsklotz',
#     'tweet_volume': None},
#    {'name': 'Evidenz',
#     'url': 'http://twitter.com/search?q=Evidenz',
#     'promoted_content': None,
#     'query': 'Evidenz',
#     'tweet_volume': None},
#    {'name': 'Treten Sie',
#     'url': 'http://twitter.com/search?q=%22Treten+Sie%22',
#     'promoted_content': None,
#     'query': '%22Treten+Sie%22',
#     'tweet_volume': None},
#    {'name': 'Gutachten',
#     'url': 'http://twitter.com/search?q=Gutachten',
#     'promoted_content': None,
#     'query': 'Gutachten',
#     'tweet_volume': None},
#    {'name': 'Wonho',
#     'url': 'http://twitter.com/search?q=Wonho',
#     'promoted_content': None,
#     'query': 'Wonho',
#     'tweet_volume': 46538},
#    {'name': 'Datenlage',
#     'url': 'http://twitter.com/search?q=Datenlage',
#     'promoted_content': None,
#     'query': 'Datenlage',
#     'tweet_volume': None},
#    {'name': 'Wirksamkeit',
#     'url': 'http://twitter.com/search?q=Wirksamkeit',
#     'promoted_content': None,
#     'query': 'Wirksamkeit',
#     'tweet_volume': None},
#    {'name': 'Opferrolle',
#     'url': 'http://twitter.com/search?q=Opferrolle',
#     'promoted_content': None,
#     'query': 'Opferrolle',
#     'tweet_volume': None},
#    {'name': 'Grundrechtseinschränkungen',
#     'url': 'http://twitter.com/search?q=Grundrechtseinschr%C3%A4nkungen',
#     'promoted_content': None,
#     'query': 'Grundrechtseinschr%C3%A4nkungen',
#     'tweet_volume': None},
#    {'name': 'Canada',
#     'url': 'http://twitter.com/search?q=Canada',
#     'promoted_content': None,
#     'query': 'Canada',
#     'tweet_volume': 387393},
#    {'name': 'Lockdown',
#     'url': 'http://twitter.com/search?q=Lockdown',
#     'promoted_content': None,
#     'query': 'Lockdown',
#     'tweet_volume': 26104},
#    {'name': 'Rücktritt',
#     'url': 'http://twitter.com/search?q=R%C3%BCcktritt',
#     'promoted_content': None,
#     'query': 'R%C3%BCcktritt',
#     'tweet_volume': None},
#    {'name': 'Bienenstich',
#     'url': 'http://twitter.com/search?q=Bienenstich',
#     'promoted_content': None,
#     'query': 'Bienenstich',
#     'tweet_volume': None},
#    {'name': 'Grundrechte',
#     'url': 'http://twitter.com/search?q=Grundrechte',
#     'promoted_content': None,
#     'query': 'Grundrechte',
#     'tweet_volume': None},
#    {'name': 'Eddie',
#     'url': 'http://twitter.com/search?q=Eddie',
#     'promoted_content': None,
#     'query': 'Eddie',
#     'tweet_volume': 395637},
#    {'name': 'Mike',
#     'url': 'http://twitter.com/search?q=Mike',
#     'promoted_content': None,
#     'query': 'Mike',
#     'tweet_volume': 253630},
#    {'name': 'bauernopfer',
#     'url': 'http://twitter.com/search?q=bauernopfer',
#     'promoted_content': None,
#     'query': 'bauernopfer',
#     'tweet_volume': None},
#    {'name': 'kommission',
#     'url': 'http://twitter.com/search?q=kommission',
#     'promoted_content': None,
#     'query': 'kommission',
#     'tweet_volume': None},
#    {'name': '#dasperfektedinner',
#     'url': 'http://twitter.com/search?q=%23dasperfektedinner',
#     'promoted_content': None,
#     'query': '%23dasperfektedinner',
#     'tweet_volume': None},
#    {'name': '#Kubicki',
#     'url': 'http://twitter.com/search?q=%23Kubicki',
#     'promoted_content': None,
#     'query': '%23Kubicki',
#     'tweet_volume': None},
#    {'name': '#RWEBMG',
#     'url': 'http://twitter.com/search?q=%23RWEBMG',
#     'promoted_content': None,
#     'query': '%23RWEBMG',
#     'tweet_volume': None},
#    {'name': '#SchleFaZ',
#     'url': 'http://twitter.com/search?q=%23SchleFaZ',
#     'promoted_content': None,
#     'query': '%23SchleFaZ',
#     'tweet_volume': None},
#    {'name': '#Evaluation',
#     'url': 'http://twitter.com/search?q=%23Evaluation',
#     'promoted_content': None,
#     'query': '%23Evaluation',
#     'tweet_volume': None},
#    {'name': '#Augstein',
#     'url': 'http://twitter.com/search?q=%23Augstein',
#     'promoted_content': None,
#     'query': '%23Augstein',
#     'tweet_volume': None},
#    {'name': '#tkschland',
#     'url': 'http://twitter.com/search?q=%23tkschland',
#     'promoted_content': None,
#     'query': '%23tkschland',
#     'tweet_volume': None},
#    {'name': '#DAZN',
#     'url': 'http://twitter.com/search?q=%23DAZN',
#     'promoted_content': None,
#     'query': '%23DAZN',
#     'tweet_volume': None},
#    {'name': '#TeamWissenschaft',
#     'url': 'http://twitter.com/search?q=%23TeamWissenschaft',
#     'promoted_content': None,
#     'query': '%23TeamWissenschaft',
#     'tweet_volume': None},
#    {'name': '#HaltDieFresseSpringerPresse',
#     'url': 'http://twitter.com/search?q=%23HaltDieFresseSpringerPresse',
#     'promoted_content': None,
#     'query': '%23HaltDieFresseSpringerPresse',
#     'tweet_volume': None},
#    {'name': '#frivolerFreitag',
#     'url': 'http://twitter.com/search?q=%23frivolerFreitag',
#     'promoted_content': None,
#     'query': '%23frivolerFreitag',
#     'tweet_volume': None},
#    {'name': '#TDF2022',
#     'url': 'http://twitter.com/search?q=%23TDF2022',
#     'promoted_content': None,
#     'query': '%23TDF2022',
#     'tweet_volume': 36845},
#    {'name': '#objektivblueten',
#     'url': 'http://twitter.com/search?q=%23objektivblueten',
#     'promoted_content': None,
#     'query': '%23objektivblueten',
#     'tweet_volume': None},
#    {'name': '#TourdeFrance',
#     'url': 'http://twitter.com/search?q=%23TourdeFrance',
#     'promoted_content': None,
#     'query': '%23TourdeFrance',
#     'tweet_volume': None},
#    {'name': '#BritishGP',
#     'url': 'http://twitter.com/search?q=%23BritishGP',
#     'promoted_content': None,
#     'query': '%23BritishGP',
#     'tweet_volume': 56977},
#    {'name': '#TheBoys',
#     'url': 'http://twitter.com/search?q=%23TheBoys',
#     'promoted_content': None,
#     'query': '%23TheBoys',
#     'tweet_volume': 56708}],
#   'as_of': '2022-07-01T19:44:29Z',
#   'created_at': '2022-06-29T05:28:44Z',
#   'locations': [{'name': 'Berlin', 'woeid': 638242}]}]

# %%
# Make a DataFrame out of this raw export
berlin_trends_df = pd.DataFrame(berlin_trends[0]['trends'])

# View the DataFrame
berlin_trends_df
# Out:
#                             name  \
# 0                        #KulFaZ
# 1                 #BluesBrothers
# 2                        Willkür
# 3               #StrangerThings4
# 4                   #DankeWieler
# 5                      Maßnahmen
# 6    #LauterbachRuecktrittSofort
# 7                     Bremsklotz
# 8                        Evidenz
# 9                     Treten Sie
# 10                     Gutachten
# 11                         Wonho
# 12                     Datenlage
# 13                   Wirksamkeit
# 14                    Opferrolle
# 15    Grundrechtseinschränkungen
# 16                        Canada
# 17                      Lockdown
# 18                     Rücktritt
# 19                   Bienenstich
# 20                   Grundrechte
# 21                         Eddie
# 22                          Mike
# 23                   bauernopfer
# 24                    kommission
# 25            #dasperfektedinner
# 26                      #Kubicki
# 27                       #RWEBMG
# 28                     #SchleFaZ
# 29                   #Evaluation
# 30                     #Augstein
# 31                    #tkschland
# 32                         #DAZN
# 33             #TeamWissenschaft
# 34  #HaltDieFresseSpringerPresse
# 35              #frivolerFreitag
# 36                      #TDF2022
# 37              #objektivblueten
# 38                 #TourdeFrance
# 39                    #BritishGP
# 40                      #TheBoys
#
#                                                   url promoted_content  \
# 0               http://twitter.com/search?q=%23KulFaZ             None
# 1        http://twitter.com/search?q=%23BluesBrothers             None
# 2            http://twitter.com/search?q=Willk%C3%BCr             None
# 3      http://twitter.com/search?q=%23StrangerThings4             None
# 4          http://twitter.com/search?q=%23DankeWieler             None
# 5          http://twitter.com/search?q=Ma%C3%9Fnahmen             None
# 6   http://twitter.com/search?q=%23LauterbachRueck...             None
# 7              http://twitter.com/search?q=Bremsklotz             None
# 8                 http://twitter.com/search?q=Evidenz             None
# 36                       %23TDF2022       36845.0
# 37               %23objektivblueten           NaN
# 38                  %23TourdeFrance           NaN
# 39                     %23BritishGP       56977.0
# 40                       %23TheBoys       56708.0

# %%
# We can again limit the list by number of tweets
berlin_top_tweets = berlin_trends_df[berlin_trends_df['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending = False)

berlin_top_tweets
# Out:
#                 name                                             url  \
# 21             Eddie               http://twitter.com/search?q=Eddie
# 16            Canada              http://twitter.com/search?q=Canada
# 3   #StrangerThings4  http://twitter.com/search?q=%23StrangerThings4
# 22              Mike                http://twitter.com/search?q=Mike
# 39        #BritishGP        http://twitter.com/search?q=%23BritishGP
# 40          #TheBoys          http://twitter.com/search?q=%23TheBoys
#
#    promoted_content               query  tweet_volume
# 21             None               Eddie      395637.0
# 16             None              Canada      387393.0
# 3              None  %23StrangerThings4      372614.0
# 22             None                Mike      253630.0
# 39             None        %23BritishGP       56977.0
# 40             None          %23TheBoys       56708.0

# %% [markdown]
# ### Common trends
#
# As both cities are very unlikely to have same trends let's try some other cities first

# %%
# Create the trends for New York variable, let's find again the ID

our_city = 'New York'

list_of_names_ny = [_ for _ in trends_worldwide if _['name'] == our_city]

print(len(list_of_names_ny))

list_of_names_ny[0]['woeid']
# Out:
# 1
# 2459115

# %%
# Get the trend now for New York this time we can use json

# Import Json
import json

# Search for New York
ny_trends =  twitter_api.trends.place(_id = 2459115)

# View the json output
print(json.dumps(ny_trends, indent = 4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Pennsylvania",
#                 "url": "http://twitter.com/search?q=Pennsylvania",
#                 "promoted_content": null,
#                 "query": "Pennsylvania",
#                 "tweet_volume": 30579
#             },
#             {
#                 "name": "#TheChi",
#                 "url": "http://twitter.com/search?q=%23TheChi",
#                 "promoted_content": null,
#                 "query": "%23TheChi",
#                 "tweet_volume": 34163
#             },
#             {
#                 "name": "byers",
#                 "url": "http://twitter.com/search?q=byers",
#                 "promoted_content": null,
#                 "query": "byers",
#                 "tweet_volume": 28983
#             },
#             {
#                 "name": "Rinna",
#                 "url": "http://twitter.com/search?q=Rinna",
#                 "promoted_content": null,
#                 "query": "Rinna",
#                 "tweet_volume": 10943
#             },
#             {
#                 "name": "#RHODubai",
#                 "url": "http://twitter.com/search?q=%23RHODubai",
#                 "promoted_content": null,
#                 "query": "%23RHODubai",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Canadians",
#                 "url": "http://twitter.com/search?q=Canadians",
#                 "promoted_content": null,
#                 "query": "Canadians",
#                 "tweet_volume": 41248
#             },
#             {
#                 "name": "#fridaymorning",
#                 "url": "http://twitter.com/search?q=%23fridaymorning",
#                 "promoted_content": null,
#                 "query": "%23fridaymorning",
#                 "tweet_volume": 17415
#             },
#             {
#                 "name": "Eddie",
#                 "url": "http://twitter.com/search?q=Eddie",
#                 "promoted_content": null,
#                 "query": "Eddie",
#                 "tweet_volume": 402176
#             },
#             {
#                 "name": "Hopper",
#                 "url": "http://twitter.com/search?q=Hopper",
#                 "promoted_content": null,
#                 "query": "Hopper",
#                 "tweet_volume": 46279
#             },
#             {
#                 "name": "They're a 10",
#                 "url": "http://twitter.com/search?q=%22They%27re+a+10%22",
#                 "promoted_content": null,
#                 "query": "%22They%27re+a+10%22",
#                 "tweet_volume": 19848
#             },
#             {
#                 "name": "Zion",
#                 "url": "http://twitter.com/search?q=Zion",
#                 "promoted_content": null,
#                 "query": "Zion",
#                 "tweet_volume": 27813
#             },
#             {
#                 "name": "Gobert",
#                 "url": "http://twitter.com/search?q=Gobert",
#                 "promoted_content": null,
#                 "query": "Gobert",
#                 "tweet_volume": 33932
#             },
#             {
#                 "name": "Pat Bev",
#                 "url": "http://twitter.com/search?q=%22Pat+Bev%22",
#                 "promoted_content": null,
#                 "query": "%22Pat+Bev%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Brogdon",
#                 "url": "http://twitter.com/search?q=Brogdon",
#                 "promoted_content": null,
#                 "query": "Brogdon",
#                 "tweet_volume": 39222
#             },
#             {
#                 "name": "Timberwolves",
#                 "url": "http://twitter.com/search?q=Timberwolves",
#                 "promoted_content": null,
#                 "query": "Timberwolves",
#                 "tweet_volume": 19446
#             },
#             {
#                 "name": "#samsummerfridays",
#                 "url": "http://twitter.com/search?q=%23samsummerfridays",
#                 "promoted_content": null,
#                 "query": "%23samsummerfridays",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Utah",
#                 "url": "http://twitter.com/search?q=Utah",
#                 "promoted_content": null,
#                 "query": "Utah",
#                 "tweet_volume": 52816
#             },
#             {
#                 "name": "#AskCardi",
#                 "url": "http://twitter.com/search?q=%23AskCardi",
#                 "promoted_content": null,
#                 "query": "%23AskCardi",
#                 "tweet_volume": 12702
#             },
#             {
#                 "name": "Celtics",
#                 "url": "http://twitter.com/search?q=Celtics",
#                 "promoted_content": null,
#                 "query": "Celtics",
#                 "tweet_volume": 75330
#             },
#             {
#                 "name": "Canada",
#                 "url": "http://twitter.com/search?q=Canada",
#                 "promoted_content": null,
#                 "query": "Canada",
#                 "tweet_volume": 391724
#             },
#             {
#                 "name": "Mitchell",
#                 "url": "http://twitter.com/search?q=Mitchell",
#                 "promoted_content": null,
#                 "query": "Mitchell",
#                 "tweet_volume": 37542
#             },
#             {
#                 "name": "Danny Ainge",
#                 "url": "http://twitter.com/search?q=%22Danny+Ainge%22",
#                 "promoted_content": null,
#                 "query": "%22Danny+Ainge%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Brad Stevens",
#                 "url": "http://twitter.com/search?q=%22Brad+Stevens%22",
#                 "promoted_content": null,
#                 "query": "%22Brad+Stevens%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Pacers",
#                 "url": "http://twitter.com/search?q=Pacers",
#                 "promoted_content": null,
#                 "query": "Pacers",
#                 "tweet_volume": 22188
#             },
#             {
#                 "name": "4th of July",
#                 "url": "http://twitter.com/search?q=%224th+of+July%22",
#                 "promoted_content": null,
#                 "query": "%224th+of+July%22",
#                 "tweet_volume": 98429
#             },
#             {
#                 "name": "stranger things",
#                 "url": "http://twitter.com/search?q=%22stranger+things%22",
#                 "promoted_content": null,
#                 "query": "%22stranger+things%22",
#                 "tweet_volume": 797319
#             },
#             {
#                 "name": "Patrick Beverly",
#                 "url": "http://twitter.com/search?q=%22Patrick+Beverly%22",
#                 "promoted_content": null,
#                 "query": "%22Patrick+Beverly%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "KAT and Rudy",
#                 "url": "http://twitter.com/search?q=%22KAT+and+Rudy%22",
#                 "promoted_content": null,
#                 "query": "%22KAT+and+Rudy%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Brit",
#                 "url": "http://twitter.com/search?q=Brit",
#                 "promoted_content": null,
#                 "query": "Brit",
#                 "tweet_volume": 18687
#             },
#             {
#                 "name": "Wyoming",
#                 "url": "http://twitter.com/search?q=Wyoming",
#                 "promoted_content": null,
#                 "query": "Wyoming",
#                 "tweet_volume": 47859
#             },
#             {
#                 "name": "Brian Windhorst",
#                 "url": "http://twitter.com/search?q=%22Brian+Windhorst%22",
#                 "promoted_content": null,
#                 "query": "%22Brian+Windhorst%22",
#                 "tweet_volume": 10994
#             },
#             {
#                 "name": "Rudy and KAT",
#                 "url": "http://twitter.com/search?q=%22Rudy+and+KAT%22",
#                 "promoted_content": null,
#                 "query": "%22Rudy+and+KAT%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Vando",
#                 "url": "http://twitter.com/search?q=Vando",
#                 "promoted_content": null,
#                 "query": "Vando",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Liz Cheney",
#                 "url": "http://twitter.com/search?q=%22Liz+Cheney%22",
#                 "promoted_content": null,
#                 "query": "%22Liz+Cheney%22",
#                 "tweet_volume": 88113
#             },
#             {
#                 "name": "Bobby Bonilla",
#                 "url": "http://twitter.com/search?q=%22Bobby+Bonilla%22",
#                 "promoted_content": null,
#                 "query": "%22Bobby+Bonilla%22",
#                 "tweet_volume": 28838
#             },
#             {
#                 "name": "Theis",
#                 "url": "http://twitter.com/search?q=Theis",
#                 "promoted_content": null,
#                 "query": "Theis",
#                 "tweet_volume": 10069
#             },
#             {
#                 "name": "Splash Mountain",
#                 "url": "http://twitter.com/search?q=%22Splash+Mountain%22",
#                 "promoted_content": null,
#                 "query": "%22Splash+Mountain%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Independence Day",
#                 "url": "http://twitter.com/search?q=%22Independence+Day%22",
#                 "promoted_content": null,
#                 "query": "%22Independence+Day%22",
#                 "tweet_volume": 41587
#             },
#             {
#                 "name": "Liberal World Order",
#                 "url": "http://twitter.com/search?q=%22Liberal+World+Order%22",
#                 "promoted_content": null,
#                 "query": "%22Liberal+World+Order%22",
#                 "tweet_volume": 129793
#             },
#             {
#                 "name": "Huerter",
#                 "url": "http://twitter.com/search?q=Huerter",
#                 "promoted_content": null,
#                 "query": "Huerter",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Windy",
#                 "url": "http://twitter.com/search?q=Windy",
#                 "promoted_content": null,
#                 "query": "Windy",
#                 "tweet_volume": 12908
#             },
#             {
#                 "name": "Tiana",
#                 "url": "http://twitter.com/search?q=Tiana",
#                 "promoted_content": null,
#                 "query": "Tiana",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "FRIDAY FACT",
#                 "url": "http://twitter.com/search?q=%22FRIDAY+FACT%22",
#                 "promoted_content": null,
#                 "query": "%22FRIDAY+FACT%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Tim Connelly",
#                 "url": "http://twitter.com/search?q=%22Tim+Connelly%22",
#                 "promoted_content": null,
#                 "query": "%22Tim+Connelly%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Nesmith",
#                 "url": "http://twitter.com/search?q=Nesmith",
#                 "promoted_content": null,
#                 "query": "Nesmith",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Rich Hill",
#                 "url": "http://twitter.com/search?q=%22Rich+Hill%22",
#                 "promoted_content": null,
#                 "query": "%22Rich+Hill%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Spida",
#                 "url": "http://twitter.com/search?q=Spida",
#                 "promoted_content": null,
#                 "query": "Spida",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Fourth of July",
#                 "url": "http://twitter.com/search?q=%22Fourth+of+July%22",
#                 "promoted_content": null,
#                 "query": "%22Fourth+of+July%22",
#                 "tweet_volume": 27256
#             },
#             {
#                 "name": "Presidential Medal of Freedom",
#                 "url": "http://twitter.com/search?q=%22Presidential+Medal+of+Freedom%22",
#                 "promoted_content": null,
#                 "query": "%22Presidential+Medal+of+Freedom%22",
#                 "tweet_volume": 10113
#             },
#             {
#                 "name": "Walker Kessler",
#                 "url": "http://twitter.com/search?q=%22Walker+Kessler%22",
#                 "promoted_content": null,
#                 "query": "%22Walker+Kessler%22",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-07-01T19:54:56Z",
#         "created_at": "2022-06-30T01:47:44Z",
#         "locations": [
#             {
#                 "name": "New York",
#                 "woeid": 2459115
#             }
#         ]
#     }
# ]

# %%
# Again limit the tweet list to those above 100,000 tweets and save it then as csv file first we need to convert to pd

ny_trends = twitter_api.trends.place(_id =list_of_names_ny[0]['woeid'])

ny_trends_pd = pd.DataFrame(ny_trends[0]['trends'])

ny_top_tweets = ny_trends_pd[ny_trends_pd['tweet_volume'] > 100000]\
.sort_values('tweet_volume', ascending = False)

ny_top_tweets.to_csv('ny_top_tweets.csv', index = False)

# %%
# Let's compare them with the london tweets, let's get the woeid again

other_city = 'London'

list_of_names_other = [_ for _ in trends_worldwide if _['name'] == other_city]

print(len(list_of_names_other))

list_of_names_other[0]['woeid']
# Out:
# 1
# 44418

# %%
london_trends = twitter_api.trends.place(_id = list_of_names_other[0]['woeid'])

london_trends_pd = pd.DataFrame(london_trends[0]['trends'])

london_trends_pd
# Out:
#                   name                                                url  \
# 0               Evelyn                 http://twitter.com/search?q=Evelyn
# 1           #BritishGP           http://twitter.com/search?q=%23BritishGP
# 2                 Gini                   http://twitter.com/search?q=Gini
# 3               yes mo           http://twitter.com/search?q=%22yes+mo%22
# 4   Danica and Charlie  http://twitter.com/search?q=%22Danica+and+Char...
# 5       #SilverstoneGP       http://twitter.com/search?q=%23SilverstoneGP
# 6                #RLCS                http://twitter.com/search?q=%23RLCS
# 7                 Ramy                   http://twitter.com/search?q=Ramy
# 8               Hopper                 http://twitter.com/search?q=Hopper
# 9            #EarpFest            http://twitter.com/search?q=%23EarpFest
# 10            Season 5         http://twitter.com/search?q=%22Season+5%22
# 11               Shane                  http://twitter.com/search?q=Shane
# 12          Copenhagen             http://twitter.com/search?q=Copenhagen
# 13      Heather Watson   http://twitter.com/search?q=%22Heather+Watson%22
# 14                Iain                   http://twitter.com/search?q=Iain
# 15         Neil Parish      http://twitter.com/search?q=%22Neil+Parish%22
# 27             None                  Tamworth           NaN
# 28             None        %22Steve+Wright%22           NaN
# 29             None         %22Scott+Mills%22           NaN
# 30             None             %22Radio+2%22       16643.0
# 31             None                    Gobert       46454.0
# 32             None                      Rams           NaN
# 33             None                    Spider       24565.0
# 34             None           %22Ken+Bruce%22           NaN
# 35             None             %22Pat+Bev%22           NaN
# 36             None                  Martinez       61104.0
# 37             None         %22Conor+Burns%22           NaN
# 38             None        %22Granit+Xhaka%22           NaN
# 39             None          %22Lickey+End%22           NaN
# 40             None        %22David+Clowes%22           NaN
# 41             None                     Toyah           NaN
# 42             None        %22Derby+County%22           NaN
# 43             None                      Pant       86505.0
# 44             None              Timberwolves       22863.0
# 45             None                      Mimi       59244.0
# 46             None                     Venus       34087.0
# 47             None            %22Mo+Salah%22       34126.0
# 48             None                    Israel       91579.0

# %% [markdown]
# ### Find common topics

# %%
# define the trend list variable for ny

ny_trend_list = [trend['name'] for trend in ny_trends[0]['trends']]

# View the output
print(ny_trend_list)
# Out:
# ['Pennsylvania', '#TheChi', 'byers', 'Rinna', '#RHODubai', 'Canadians', '#fridaymorning', 'Eddie', 'hopper', "They're a 10", 'Zion', 'Gobert', 'Pat Bev', 'Pat Bev', 'Timberwolves', 'Brogdon', '#samsummerfridays', '#AskCardi', 'Mitchell', 'Celtics', 'Canada', 'Danny Ainge', 'Brad Stevens', 'Pacers', 'Patrick Beverly', '4th of July', 'stranger things', 'KAT and Rudy', 'Brian Windhorst', 'Walker Kessler', 'Brit', 'Vando', 'Rudy and KAT', 'Wyoming', 'Tim Connelly', 'Liz Cheney', 'Windy', 'Spida', 'Bobby Bonilla', 'Independence Day', 'Beasley', 'Theis', 'Voyager', 'Splash Mountain', 'Rich Hill', 'Minny', 'McDaniels', 'Liberal World Order', 'Huerter', 'Tiana']

# %%
# define the trend list variable for lodon

london_trend_list = [trend['name'] for trend in london_trends[0]['trends']]

# View the output
print(london_trend_list)
# Out:
# ['Evelyn', '#BritishGP', 'Gini', 'yes mo', 'Danica and Charlie', '#SilverstoneGP', '#RLCS', 'Ramy', 'Hopper', '#EarpFest', 'Season 5', 'Shane', 'Copenhagen', 'Heather Watson', 'Iain', 'Neil Parish', 'Adele', 'Eddie Munson', 'Camara', 'BloJo', 'Williamson', 'Claudia Webbe', 'Butter', 'British Grand Prix', 'Somme', 'Moshiri', 'Debbie Harry', 'Tamworth', 'Steve Wright', 'Scott Mills', 'Radio 2', 'Gobert', 'Rams', 'Spider', 'Ken Bruce', 'Pat Bev', 'Martinez', 'Conor Burns', 'Granit Xhaka', 'Lickey End', 'David Clowes', 'Toyah', 'Derby County', 'Pant', 'Timberwolves', 'Mimi', 'Venus', 'Mo Salah', 'Israel']

# %%
# Now we have both lists of all trending topics, lets compare them by creting sets of these lists
ny_trends_sets = set(ny_trend_list)
london_trend_set = set(london_trend_list)

# Set the variable
common_trends = ny_trends_sets.intersection(london_trend_set)

# View the output
print(common_trends)
# Out:
# {'Gobert', 'Pat Bev', 'Timberwolves'}
